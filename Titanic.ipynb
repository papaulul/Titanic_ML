# %% [markdown]
# # Titanic

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
sns.set_style('whitegrid')
# %matplotlib inline

# %%
train = pd.read_csv('train.csv')

# %%
test = pd.read_csv('test.csv')

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
test.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# ...

# %%
# plt.figure(figsize=(12,6))
# sns.heatmap(train.isna())

# %%
# plt.figure(figsize=(12,6))
# sns.heatmap(test.isna())

# %%
# train['Age'].dropna().plot.hist(bins=25)

# %%
# test['Age'].dropna().plot.hist(bins=25)

# %%
train['Age'].fillna(train['Age'].dropna().median(),inplace=True)

# %%
test['Age'].fillna(test['Age'].dropna().median(),inplace=True)

# %%
# plt.figure(figsize=(12,6))
# sns.heatmap(train.isna())

# %%
# plt.figure(figsize=(12,6))
# sns.heatmap(test.isna())

# %%
train.drop('Cabin',axis=1,inplace=True)

# %%
test.drop('Cabin',axis=1,inplace=True)

# %%
train.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
test.isna().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %%
train.dropna(inplace=True)

# %%
train.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
test['Fare'][152]=test['Fare'].median(skipna=True)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
test.isna().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
train.drop(['PassengerId','Ticket'],axis=1, inplace=True)
test.drop(['Ticket'],axis=1, inplace=True)

# %%
train.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked
# 0    male  22.0      1      0   7.2500        S
# 1  female  38.0      1      0  71.2833        C
# 2  female  26.0      0      0   7.9250        S
# 3  female  35.0      1      0  53.1000        S
# 4    male  35.0      0      0   8.0500        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch     Fare Embarked
# 0  34.5      0      0   7.8292        Q
# 1  47.0      1      0   7.0000        S
# 2  62.0      0      0   9.6875        Q
# 3  27.0      0      0   8.6625        S
# 4  22.0      1      1  12.2875        S

# %%
def is_alone(cols):
    Age=cols[0]
    sibsp = cols[1]
    parch = cols[2]
    if (sibsp + parch) == 0:
        if Age > 16:
            return 1
        else:
            return 0
    else: 
        return 0

# %%
train['Alone'] = train[['Age','SibSp','Parch']].apply(is_alone,axis=1)
test['Alone'] = test[['Age','SibSp','Parch']].apply(is_alone,axis=1)

# %%
train.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked  Alone
# 0    male  22.0      1      0   7.2500        S      0
# 1  female  38.0      1      0  71.2833        C      0
# 2  female  26.0      0      0   7.9250        S      1
# 3  female  35.0      1      0  53.1000        S      0
# 4    male  35.0      0      0   8.0500        S      1

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch     Fare Embarked  Alone
# 0  34.5      0      0   7.8292        Q      1
# 1  47.0      1      0   7.0000        S      0
# 2  62.0      0      0   9.6875        Q      1
# 3  27.0      0      0   8.6625        S      1
# 4  22.0      1      1  12.2875        S      0

# %%
train['title']=train['Name'].apply(lambda name: name.split(sep=',')[1].split(sep='.')[0].strip())
test['title'] =test['Name'].apply(lambda name: name.split(sep=',')[1].split(sep='.')[0].strip())

# %%
train.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked  Alone title
# 0    male  22.0      1      0   7.2500        S      0    Mr
# 1  female  38.0      1      0  71.2833        C      0   Mrs
# 2  female  26.0      0      0   7.9250        S      1  Miss
# 3  female  35.0      1      0  53.1000        S      0   Mrs
# 4    male  35.0      0      0   8.0500        S      1    Mr

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch     Fare Embarked  Alone title
# 0  34.5      0      0   7.8292        Q      1    Mr
# 1  47.0      1      0   7.0000        S      0   Mrs
# 2  62.0      0      0   9.6875        Q      1    Mr
# 3  27.0      0      0   8.6625        S      1    Mr
# 4  22.0      1      1  12.2875        S      0   Mrs

# %%
train.drop('Name', axis=1,inplace=True)
test.drop('Name', axis=1,inplace=True)

# %%
train.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  Alone title
# 0         0       3    male  22.0      1      0   7.2500        S      0    Mr
# 1         1       1  female  38.0      1      0  71.2833        C      0   Mrs
# 2         1       3  female  26.0      0      0   7.9250        S      1  Miss
# 3         1       1  female  35.0      1      0  53.1000        S      0   Mrs
# 4         0       3    male  35.0      0      0   8.0500        S      1    Mr

# %%
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  Alone  \
# 0          892       3    male  34.5      0      0   7.8292        Q      1
# 1          893       3  female  47.0      1      0   7.0000        S      0
# 2          894       2    male  62.0      0      0   9.6875        Q      1
# 3          895       3    male  27.0      0      0   8.6625        S      1
# 4          896       3  female  22.0      1      1  12.2875        S      0
#
#   title
# 0    Mr
# 1   Mrs
# 2    Mr
# 3    Mr
# 4   Mrs

# %%
items=['Sex','Embarked']
for cols in items:
    add = pd.get_dummies(train[cols],drop_first=True)
    train=pd.concat([train,add], axis=1)

# %%
items=['Sex','Embarked']
for cols in items:
    add = pd.get_dummies(test[cols],drop_first=True)
    test=pd.concat([test,add], axis=1)

# %%
train.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  Alone  \
# 0         0       3    male  22.0      1      0   7.2500        S      0
# 1         1       1  female  38.0      1      0  71.2833        C      0
# 2         1       3  female  26.0      0      0   7.9250        S      1
# 3         1       1  female  35.0      1      0  53.1000        S      0
# 4         0       3    male  35.0      0      0   8.0500        S      1
#
#   title  male  Q  S
# 0    Mr     1  0  1
# 1   Mrs     0  0  0
# 2  Miss     0  0  1
# 3   Mrs     0  0  1
# 4    Mr     1  0  1

# %%
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  Alone  \
# 0          892       3    male  34.5      0      0   7.8292        Q      1
# 1          893       3  female  47.0      1      0   7.0000        S      0
# 2          894       2    male  62.0      0      0   9.6875        Q      1
# 3          895       3    male  27.0      0      0   8.6625        S      1
# 4          896       3  female  22.0      1      1  12.2875        S      0
#
#   title  male  Q  S
# 0    Mr     1  1  0
# 1   Mrs     0  0  1
# 2    Mr     1  1  0
# 3    Mr     1  0  1
# 4   Mrs     0  0  1

# %%
train.drop(items,axis=1,inplace=True)
train.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Alone title  male  Q  S
# 0         0       3  22.0      1      0   7.2500      0    Mr     1  0  1
# 1         1       1  38.0      1      0  71.2833      0   Mrs     0  0  0
# 2         1       3  26.0      0      0   7.9250      1  Miss     0  0  1
# 3         1       1  35.0      1      0  53.1000      0   Mrs     0  0  1
# 4         0       3  35.0      0      0   8.0500      1    Mr     1  0  1

# %%
test.drop(items,axis=1,inplace=True)
test.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  Alone title  male  Q  S
# 0          892       3  34.5      0      0   7.8292      1    Mr     1  1  0
# 1          893       3  47.0      1      0   7.0000      0   Mrs     0  0  1
# 2          894       2  62.0      0      0   9.6875      1    Mr     1  1  0
# 3          895       3  27.0      0      0   8.6625      1    Mr     1  0  1
# 4          896       3  22.0      1      1  12.2875      0   Mrs     0  0  1

# %% [markdown]
# # Logistic Regression

# %%
train.drop('title',axis=1,inplace=True)

# %%
X= train.drop('Survived', axis=1)
y= train['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size =.3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lm = LogisticRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions = lm.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.86      0.84      0.85       173
#           1       0.72      0.76      0.74        94
#
# avg / total       0.81      0.81      0.81       267
#
# [[145  28]
#  [ 23  71]]

# %% [markdown]
# # Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predictions = dtree.predict(X_test)

# %%
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.84      0.80      0.82       173
#           1       0.66      0.72      0.69        94
#
# avg / total       0.78      0.77      0.77       267
#
# [[138  35]
#  [ 26  68]]

# %% [markdown]
# #   Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=20000)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20000, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
predictions = rfc.predict(X_test)

# %%
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.89      0.77      0.83       173
#           1       0.66      0.82      0.73        94
#
# avg / total       0.81      0.79      0.79       267
#
# [[134  39]
#  [ 17  77]]

# %% [markdown]
# # Support Vector Classifier

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(X_train,y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
predictions = model.predict(X_test)

# %%
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[137  36]
#  [ 38  56]]
#              precision    recall  f1-score   support
#
#           0       0.78      0.79      0.79       173
#           1       0.61      0.60      0.60        94
#
# avg / total       0.72      0.72      0.72       267

# %%
param_grid = {'C': [0.1,1, 10, 100, 1000,10000], 'gamma': [1,0.1,0.01,0.001,0.0001,.00001], 'kernel': ['rbf']}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)

# %%
# May take awhile!
grid.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV]  C=0.1, gamma=1, kernel=rbf, score=0.6057692307692307, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV]  C=0.1, gamma=1, kernel=rbf, score=0.6038647342995169, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV]  C=0.1, gamma=1, kernel=rbf, score=0.6038647342995169, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV]  C=0.1, gamma=0.1, kernel=rbf, score=0.6057692307692307, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV]  C=0.1, gamma=0.1, kernel=rbf, score=0.6038647342995169, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV]  C=0.1, gamma=0.1, kernel=rbf, score=0.6038647342995169, total=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'C': 10000, 'gamma': 1e-05, 'kernel': 'rbf'}

# %%
grid.best_estimator_
# Out:
# SVC(C=10000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=1e-05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
grid_predictions = grid.predict(X_test)

# %%
print(confusion_matrix(y_test,grid_predictions))
print(classification_report(y_test,grid_predictions))
# Out:
# [[149  24]
#  [ 24  70]]
#              precision    recall  f1-score   support
#
#           0       0.86      0.86      0.86       173
#           1       0.74      0.74      0.74        94
#
# avg / total       0.82      0.82      0.82       267

# %% [markdown]
# # Scores

# %%
grid.score(X_test,y_test)
# Out:
# 0.8202247191011236

# %%
lm.score(X_test,y_test)
# Out:
# 0.8089887640449438

# %%
rfc.score(X_test,y_test)
# Out:
# 0.79026217228464424

# %%
dtree.score(X_test,y_test)
# Out:
# 0.77153558052434457

# %% [markdown]
# # Tensorflow

# %%
import tensorflow as tf
from sklearn import metrics

# %%
import tensorflow.contrib.learn as learn
feature_columns = tf.contrib.learn.infer_real_valued_columns_from_input(X_train)
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.

# %%
 classifier = tf.contrib.learn.DNNClassifier(
      feature_columns=feature_columns, hidden_units=[10, 20, 10], n_classes=9)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/0w/9c65zv0x3_v9t2mcg5rpj6580000gp/T/tmpkmrje9m1
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1c37065ba8>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/var/folders/0w/9c65zv0x3_v9t2mcg5rpj6580000gp/T/tmpkmrje9m1'}

# %%
  classifier.fit(X_train, y_train, steps=20000)
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/0w/9c65zv0x3_v9t2mcg5rpj6580000gp/T/tmpkmrje9m1/model.ckpt.
# INFO:tensorflow:loss = 6.53925, step = 1
# INFO:tensorflow:global_step/sec: 58.8393
# INFO:tensorflow:loss = 0.589448, step = 101 (1.702 sec)
# INFO:tensorflow:global_step/sec: 47.632
# INFO:tensorflow:loss = 0.548356, step = 201 (2.098 sec)
# INFO:tensorflow:global_step/sec: 50.2224
# INFO:tensorflow:loss = 0.507877, step = 301 (1.991 sec)
# INFO:tensorflow:global_step/sec: 71.2337
# INFO:tensorflow:loss = 0.47931, step = 401 (1.404 sec)
# INFO:tensorflow:global_step/sec: 72.6672
# INFO:tensorflow:loss = 0.462034, step = 501 (1.377 sec)
# INFO:tensorflow:global_step/sec: 73.1146
# INFO:tensorflow:loss = 0.452198, step = 601 (1.367 sec)
# INFO:tensorflow:global_step/sec: 72.2806
# ...

# %%
  predictions = list(classifier.predict(X_test, as_iterable=True))
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Restoring parameters from /var/folders/0w/9c65zv0x3_v9t2mcg5rpj6580000gp/T/tmpkmrje9m1/model.ckpt-20000

# %%
  score = metrics.accuracy_score(y_test, predictions)
  print('Accuracy: {0:f}'.format(score))
# Out:
# Accuracy: 0.801498

# %% [markdown]
# # 60/40 split

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X,y,test_size =.4)

# %%
lm = LogisticRegression()
lm.fit(X1_train,y1_train)
predictions = lm.predict(X1_test)
print(classification_report(y1_test, predictions))
print(confusion_matrix(y1_test, predictions))
lm.score(X1_test,y1_test)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.82      0.89      0.85       223
#           1       0.78      0.68      0.73       133
#
# avg / total       0.81      0.81      0.81       356
#
# [[198  25]
#  [ 43  90]]
# 0.8089887640449438

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X1_train,y1_train)
predictions = dtree.predict(X1_test)
print(classification_report(y1_test, predictions))
print(confusion_matrix(y1_test, predictions))
dtree.score(X1_test,y1_test)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.84      0.89      0.86       223
#           1       0.79      0.71      0.75       133
#
# avg / total       0.82      0.82      0.82       356
#
# [[198  25]
#  [ 38  95]]
# 0.8230337078651685

# %%
rfc = RandomForestClassifier(n_estimators=20000)
rfc.fit(X1_train,y1_train)
predictions = rfc.predict(X1_test)
print(classification_report(y1_test, predictions))
print(confusion_matrix(y1_test, predictions))
rfc.score(X1_test,y1_test)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.86      0.91      0.88       223
#           1       0.83      0.75      0.79       133
#
# avg / total       0.85      0.85      0.85       356
#
# [[202  21]
#  [ 33 100]]
# 0.848314606741573

# %%
grid.fit(X1_train,y1_train)
grid.best_params_
grid.best_estimator_
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV]  C=0.1, gamma=1, kernel=rbf, score=0.6123595505617978, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV]  C=0.1, gamma=1, kernel=rbf, score=0.6123595505617978, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV]  C=0.1, gamma=1, kernel=rbf, score=0.6101694915254238, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV]  C=0.1, gamma=0.1, kernel=rbf, score=0.6123595505617978, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV]  C=0.1, gamma=0.1, kernel=rbf, score=0.6123595505617978, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV]  C=0.1, gamma=0.1, kernel=rbf, score=0.6101694915254238, total=   0.0s
# ...

# %%
grid_predictions = grid.predict(X1_test)
print(confusion_matrix(y1_test,grid_predictions))
print(classification_report(y1_test,grid_predictions))
grid.score(X1_test,y1_test)
# Out:
# [[192  31]
#  [ 41  92]]
#              precision    recall  f1-score   support
#
#           0       0.82      0.86      0.84       223
#           1       0.75      0.69      0.72       133
#
# avg / total       0.80      0.80      0.80       356
# 0.797752808988764

# %%
feature_columns = tf.contrib.learn.infer_real_valued_columns_from_input(X1_train)
classifier = tf.contrib.learn.DNNClassifier(
      feature_columns=feature_columns, hidden_units=[10, 20, 10], n_classes=9)
classifier.fit(X1_train, y1_train, steps=20000)
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/0w/9c65zv0x3_v9t2mcg5rpj6580000gp/T/tmpld1p87h1
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1c35bd5588>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/var/folders/0w/9c65zv0x3_v9t2mcg5rpj6580000gp/T/tmpld1p87h1'}
# ...

# %%
predictions = list(classifier.predict(X1_test, as_iterable=True))
score = metrics.accuracy_score(y1_test, predictions)
print('Accuracy: {0:f}'.format(score))
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Restoring parameters from /var/folders/0w/9c65zv0x3_v9t2mcg5rpj6580000gp/T/tmpld1p87h1/model.ckpt-20000
# Accuracy: 0.800562

# %%
X_actual_train = train.drop('Survived',axis=1)
# X_actual_train = X_actual_train.drop('Fare',axis=1)
y_actual_train = train['Survived']
X_actual_test = test.drop(['PassengerId','title'],axis=1).copy()
# X_actual_test = X_actual_test.drop('Fare',axis=1)

# %%
X_actual_train.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Alone  male  Q  S
# 0       3  22.0      1      0   7.2500      0     1  0  1
# 1       1  38.0      1      0  71.2833      0     0  0  0
# 2       3  26.0      0      0   7.9250      1     0  0  1
# 3       1  35.0      1      0  53.1000      0     0  0  1
# 4       3  35.0      0      0   8.0500      1     1  0  1

# %%
lm = LogisticRegression()
lm.fit(X_actual_train,y_actual_train)
predictions = lm.predict(X_actual_test)

# %%
rfc.fit(X_train,y_train)
predictions1 = rfc.predict(X_actual_test)

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": predictions1
    })

# %%
submission.to_csv('submission.csv', index=False)

# %%
submission1 = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": predictions
    })

# %%
submission1.to_csv('submission.csv', index=False)

# %%
grid_predictions = grid.predict(X_actual_test)
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": grid_predictions
    })
submission.to_csv('submission.csv', index=False)

# %%
feature_columns = tf.contrib.learn.infer_real_valued_columns_from_input(X_actual_train)
classifier = tf.contrib.learn.DNNClassifier(
      feature_columns=feature_columns, hidden_units=[10, 20, 10], n_classes=9)
classifier.fit(X_actual_train, y_actual_train, steps=20000)
predictions = list(classifier.predict(X_actual_test, as_iterable=True))
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/0w/9c65zv0x3_v9t2mcg5rpj6580000gp/T/tmptvgle3ap
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1c363f7780>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/var/folders/0w/9c65zv0x3_v9t2mcg5rpj6580000gp/T/tmptvgle3ap'}
# ...

# %%
submission1 = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": predictions
    })
submission1.to_csv('submission.csv', index=False)
